# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
final_act=[]
final_pred=[]

# %%
df=pd.read_csv('/home/ictd/nishant/research/Project/Results/Processed/azadpur_arrival.csv')

# %%
df=np.array(df['arrival'])

# %%
df=df.reshape(df.shape[0],1)

# %%
scaler = StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
import pickle
predicted_list = []
with open('/home/ictd/nishant/research/Project/Results/Drive1/Arrival/Delhi/pred4270:4660.pkl', 'rb') as fr:
    try:
        while True:
            predicted_list.append(pickle.load(fr))
    except EOFError:
        pass
flat_pred = [item for sublist in predicted_list for item in sublist]

# %%
len(flat_pred)
# Out:
# 4660

# %%
final_pred=final_pred+list(flat_pred[4270:4660])

# %%
len(final_pred)
# Out:
# 390

# %%
final_pred
# Out:
# [732.542,
#  732.7634,
#  730.01245,
#  730.8799,
#  737.6927,
#  741.52985,
#  743.0163,
#  735.5486,
#  737.2521,
#  736.01086,
#  733.6472,
#  738.99207,
#  729.16547,
#  739.1745,
#  734.4627,
#  726.8094,
#  738.0276,
#  731.71686,
#  736.71027,
#  739.7218,
#  742.2628,
#  751.87134,
#  743.6091,
#  741.5613,
#  745.3978,
#  751.1175,
#  752.2829,
#  743.7986,
#  750.5782,
#  749.3322,
#  784.10114,
#  795.1381,
#  803.4461,
#  801.7839,
#  804.82837,
#  808.43317,
#  817.6829,
#  805.007,
#  796.8167,
#  812.2251,
#  817.55286,
#  815.60297,
#  807.47876,
#  818.5475,
#  815.40173,
#  812.191,
#  818.5914,
#  817.3874,
#  824.3166,
#  819.482,
#  840.26575,
#  839.4993,
#  827.0396,
#  825.05206,
#  816.55347,
#  826.162,
#  821.4447,
#  807.13965,
#  824.06354,
#  822.68304,
#  746.7146,
#  755.7006,
#  755.2302,
#  760.28864,
#  762.8222,
#  772.2763,
#  775.3506,
#  762.3195,
#  764.33246,
#  771.3156,
#  767.81665,
#  768.7121,
#  761.72516,
#  776.4014,
#  772.72064,
# ...

# %%
pd.DataFrame(final_pred).to_csv('finalpred.csv')
