# %%
import pandas as pd

# %%
df=pd.read_csv('2018potatonews.csv')

# %%
df[130:]
# Out:
#      Unnamed: 0                                       articleTitle  \
# 130         130                           Punjab’s burning problem
# 131         131     Centre lifts ban on marketing of Lahaul potato
# 132         132  Govt. moves to plug leakages in public distrib...
# 133         133     MoFPI approves strategy for ‘Operation Greens’
# 134         134  WPI inflation hits 4-month high; RBI may maint...
# 135         135  One dead, scores injured in fuel tax protests ...
# 136         136                       Onion prices hit rock bottom
# 137         137     Sikkim pushes for export of organic vegetables
# 138         138  Deesa potato farmers stare at glut, falling pr...
# 139         139  Industry bodies wants restrictions on cross-bo...
# 140         140          Can Mars be colonised in the near future?
# 141         141  Potatoes to be stored for free in government b...
# 142         142  Cyclone damaged 17,470 acres of horticulture c...
# ...

# %%
df.iloc[153]['text']
# Out:
# 'This story is from December 21, 2018Picture used for representational purpose onlyDownload The Times of India News App for Latest CityJALANDHAR: Already battling with loses of the previous two years, the potato growers in Punjab are staring at another bad year with prices of the crop crashing to the bottom. Whats worse, some of the leftover stock of last year is still lying with them.The farmers claim that they are unable recover even their cost of production and harvesting as the price is down to Rs 3 per kg. When the harvesting of potatoes started, which are supplied directly in the market for domestic consumption, the price was at Rs 20-25 per kg. That was three weeks back, now it has crashed to Rs 3 a kg. While, Jalandhar is largely a seed producingbelt for the country, farmers here also harvest part of their crop for supplies in the local market, said Jalandhar Potato Growers Association (JPGA) general secretary Jaswinder Singh Sangha.Cost of production, harvesting and packing 
# ...

# %%
[9,35,64,122]

# %%
dk=df.iloc[[9,35,64,122]]

# %%
dk.to_csv('2018final.csv')

# %%
dk
# Out:
#      Unnamed: 0                                       articleTitle  \
# 9             9  Farmers’ protest? Potatoes thrown on Lucknow r...
# 35           35                                    Potato portents
# 64           64    UP government doubles potato procurement target
# 122         122  Sharp fall in supplies drives up prices of pot...
#
#                                             articleUrl publishedDate  \
# 9    http://www.thehindu.com/todays-paper/farmers-p...    2018-01-07
# 35   https://indianexpress.com/article/opinion/colu...    2018-01-23
# 64   http://timesofindia.indiatimes.com//city/barei...    2018-03-05
# 122  https://timesofindia.indiatimes.com/india/shar...    2018-06-09
#
#              sourceName                                               text
# 9             The Hindu  Potatoes were hurled from a truck at various p...
# 35       Indian Express  The loss incurred by a farmer in just two crop...
# ...
