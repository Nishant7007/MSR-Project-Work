# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/home/nishant/study/researchwork/MSThesis-Time_Series_Forecasting-master/Data/original/Raw/lucknow_mandi.csv',header=None)

# %%
df.head()
# Out:
#             0   1    2
# 0  2006-01-01  40  0.0
# 1  2006-01-02  40  0.0
# 2  2006-01-03  40  0.0
# 3  2006-01-04  40  0.0
# 4  2006-01-05  40  0.0

# %%
df=df[df[0]>='2006-01-01']

# %%
df.head()
# Out:
#             0   1    2
# 0  2006-01-01  40  0.0
# 1  2006-01-02  40  0.0
# 2  2006-01-03  40  0.0
# 3  2006-01-04  40  0.0
# 4  2006-01-05  40  0.0

# %%
df.drop_duplicates(subset=0,inplace=True)

# %%
import pandas as pd

idx = pd.date_range('2006-01-01', '2019-12-31')

df.index = pd.DatetimeIndex(df[0])

df = df.reindex(idx, fill_value=0)

# %%
df[0]=df.index

# %%
df.head()
# Out:
#                     0   1    2
# 2006-01-01 2006-01-01  40  0.0
# 2006-01-02 2006-01-02  40  0.0
# 2006-01-03 2006-01-03  40  0.0
# 2006-01-04 2006-01-04  40  0.0
# 2006-01-05 2006-01-05  40  0.0

# %%
df[3]=df[2]

# %%
df.head()
# Out:
#                     0   1    2    3
# 2006-01-01 2006-01-01  40  0.0  0.0
# 2006-01-02 2006-01-02  40  0.0  0.0
# 2006-01-03 2006-01-03  40  0.0  0.0
# 2006-01-04 2006-01-04  40  0.0  0.0
# 2006-01-05 2006-01-05  40  0.0  0.0

# %%
df[2].replace(0.0,np.nan,inplace=True)

# %%
df[2]=df[2].interpolate(method='pchip')

# %%
df.tail()
# Out:
#                     0   1       2       3
# 2019-12-27 2019-12-27  40  1500.0  1500.0
# 2019-12-28 2019-12-28  40  1475.0  1475.0
# 2019-12-29 2019-12-29  40  1400.0  1400.0
# 2019-12-30 2019-12-30  40  1350.0  1350.0
# 2019-12-31 2019-12-31  40  1330.0     0.0

# %%
df.loc[df[3] != 0.0, 3] = 1

# %%
#df[2]*=100

# %%
len(df)
# Out:
# 5113

# %%
df=df[[0,2,3]]

# %%
df
# Out:
#                     0       2    3
# 2006-01-01 2006-01-01     NaN  0.0
# 2006-01-02 2006-01-02     NaN  0.0
# 2006-01-03 2006-01-03     NaN  0.0
# 2006-01-04 2006-01-04     NaN  0.0
# 2006-01-05 2006-01-05     NaN  0.0
# 2006-01-06 2006-01-06     NaN  0.0
# 2006-01-07 2006-01-07     NaN  0.0
# 2006-01-08 2006-01-08     NaN  0.0
# 2006-01-09 2006-01-09     NaN  0.0
# 2006-01-10 2006-01-10     NaN  0.0
# 2006-01-11 2006-01-11     NaN  0.0
# 2006-01-12 2006-01-12     NaN  0.0
# 2006-01-13 2006-01-13     NaN  0.0
# 2006-01-14 2006-01-14     NaN  0.0
# 2006-01-15 2006-01-15     NaN  0.0
# 2006-01-16 2006-01-16     NaN  0.0
# 2006-01-17 2006-01-17     NaN  0.0
# 2006-01-18 2006-01-18     NaN  0.0
# 2006-01-19 2006-01-19     NaN  0.0
# 2006-01-20 2006-01-20     NaN  0.0
# 2006-01-21 2006-01-21     NaN  0.0
# 2006-01-22 2006-01-22     NaN  0.0
# 2006-01-23 2006-01-23     NaN  0.0
# 2006-01-24 2006-01-24     NaN  0.0
# 2006-01-25 2006-01-25     NaN  0.0
# 2006-01-26 2006-01-26     NaN  0.0
# ...

# %%
df.to_csv('/home/nishant/study/researchwork/MSThesis-Time_Series_Forecasting-master/Data/website/Mandi/lucknow_mandi.csv',header=None,index=False)

# %%
df=pd.read_csv('/home/nishant/study/researchwork/MSThesis-Time_Series_Forecasting-master/Data/website/Mandi/lucknow_mandi.csv',header=None)

# %%
df[1]=df[1].rolling(30).mean()

# %%
df.to_csv('/home/nishant/study/researchwork/MSThesis-Time_Series_Forecasting-master/Data/website/Mandi/lucknow_mandi_smooth.csv',header=None,index=False)

# %%
df
# Out:
#                0            1    2
# 0     2006-01-01          NaN  0.0
# 1     2006-01-02          NaN  0.0
# 2     2006-01-03          NaN  0.0
# 3     2006-01-04          NaN  0.0
# 4     2006-01-05          NaN  0.0
# 5     2006-01-06          NaN  0.0
# 6     2006-01-07          NaN  0.0
# 7     2006-01-08          NaN  0.0
# 8     2006-01-09          NaN  0.0
# 9     2006-01-10          NaN  0.0
# 10    2006-01-11          NaN  0.0
# 11    2006-01-12          NaN  0.0
# 12    2006-01-13          NaN  0.0
# 13    2006-01-14          NaN  0.0
# 14    2006-01-15          NaN  0.0
# 15    2006-01-16          NaN  0.0
# 16    2006-01-17          NaN  0.0
# 17    2006-01-18          NaN  0.0
# 18    2006-01-19          NaN  0.0
# 19    2006-01-20          NaN  0.0
# 20    2006-01-21          NaN  0.0
# 21    2006-01-22          NaN  0.0
# 22    2006-01-23          NaN  0.0
# 23    2006-01-24          NaN  0.0
# 24    2006-01-25          NaN  0.0
# 25    2006-01-26          NaN  0.0
# ...

# %%
len(df[df[2]==0.0])
# Out:
# 1000

# %%
len(df[df[2]!=0.0])
# Out:
# 4113
